# %%
# machine learning
    #superised
      #classification 
      #regression
      #X-Independent variable
      #Y- Dependent variable
    #unsupervised
      #clustering
    #reinforcement
      #forecasting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\DS 9-1\STATS\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#Linear regression

# %%
# 1. Assumption checking

# %%
#1. Linearity
#2. no multi- linearity between independent variables ( in that case u need to drop either of the column)
#3.Auto correlation should not be there (ie. next value should not depend on previous value in the same column)
#4. no outliers
#5. no null values
#6. char-numbers-NA

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
plt.boxplot(df["TV"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768b07d2b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768b07d9a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768b01af10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2768b09d0a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2768b09d400>],
#  'means': []}

# %%
plt.boxplot(df["radio"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768b2166a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768b216d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768b216340>],
#  'medians': [<matplotlib.lines.Line2D at 0x2768b263460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2768b2637c0>],
#  'means': []}

# %%
box=plt.boxplot(df["newspaper"])

# %%
plt.boxplot(df["sales"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768aef3280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768aef3940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768b444ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2768aef5040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2768aef5340>],
#  'means': []}

# %%
box=plt.boxplot(df["newspaper"])

# %%
box
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768acc72b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768acc79a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768acc2f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2768acd20a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2768acd2400>],
#  'means': []}

# %%
for i in box["fliers"]:
    print(i.get_ydata())
# Out:
# [114.  100.9]

# %%
for i in box["whiskers"]:
    print(i.get_ydata())
# Out:
# [12.75  0.3 ]
# [45.1 89.4]

# %%
#droping outliers from fliers

# %%
df[df["newspaper"]>100]
# Out:
#         TV  radio  newspaper  sales
# 16    67.8   36.6      114.0   12.5
# 101  296.4   36.3      100.9   23.8

# %%
df[df["newspaper"]<100]
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
df1=df[df["newspaper"]<100]

# %%
df1
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
box=plt.boxplot(df1["newspaper"])

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.051978   0.049771  0.779121
# radio      0.051978  1.000000   0.346364  0.576748
# newspaper  0.049771  0.346364   1.000000  0.219555
# sales      0.779121  0.576748   0.219555  1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768c74e340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768c74ea00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768c740fa0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2768c756100>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2768c756460>,
# ...
#  'means': []}

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2768c7bf700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2768c7bfdf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2768c7bf3a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2768c7ca4f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2768c7ca850>,
# ...
#  'means': []}

# %%
df1.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
for i in df1.columns:
    print(df1[i].unique())
# Out:
# [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4 281.4  69.2 147.3 218.4 237.4  13.2 228.3  62.3
#  262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7 266.9
#   74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9 227.2
#   66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5 261.3
#  239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4 213.4
#   16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2  76.3
#  110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7 135.2
#  222.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8 241.7 175.7
#  209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1 229.5  87.2
#    7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3  25.6 273.7
#   43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7 280.7 121.
#  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4 163.5 117.2
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         198 non-null    float64
#  1   radio      198 non-null    float64
#  2   newspaper  198 non-null    float64
#  3   sales      198 non-null    float64
# dtypes: float64(4)
# memory usage: 7.7 KB

# %%
df1.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df1.columns.unique()
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
new_data=pd.read_csv("D:\\DS 9-1\\python file\\adult_new.csv")

# %%
new_data
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       28         Local-gov  336951    Assoc-acdm               12
# 1       44           Private  160323  Some-college               10
# 2       63  Self-emp-not-inc  104626   Prof-school               15
# 3       65           Private  184454       HS-grad                9
# 4       48           Private  279724       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 27409   27           Private  257302    Assoc-acdm               12
# 27410   40           Private  154374       HS-grad                9
# 27411   58           Private  151910       HS-grad                9
# 27412   22           Private  201490       HS-grad                9
# 27413   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0      Married-civ-spouse    Protective-serv      Husband  White    Male
# ...

# %%
for i in new_data.columns:
    print(new_data[i].unique())
# Out:
# [28 44 63 65 48 43 40 34 45 46 36 22 42 41 55 33 59 29 27 31 58 54 37 56
#  39 51 50 52 47 24 64 53 35 32 30 68 57 66 49 38 61 73 26 23 25 62 90 60
#  67 69 72 85 71 77 70 19 21 74 75 20 81 76 80 88 78 79 84 17 18 82 83 86
#  87]
# ['Local-gov' 'Private' 'Self-emp-not-inc' 'State-gov' 'Self-emp-inc' '?'
#  'Federal-gov' 'Without-pay' 'Never-worked']
# [336951 160323 104626 ...  84661 310152 257302]
# ['Assoc-acdm' 'Some-college' 'Prof-school' 'HS-grad' 'Masters' 'Doctorate'
#  'Bachelors' 'Assoc-voc' '9th' '10th' '7th-8th' '11th' '5th-6th' '1st-4th'
#  '12th' 'Preschool']
# [12 10 15  9 14 16 13 11  5  6  4  7  3  2  8  1]
# ['Married-civ-spouse' 'Never-married' 'Divorced' 'Separated'
#  'Married-AF-spouse' 'Widowed' 'Married-spouse-absent']
# ['Protective-serv' 'Machine-op-inspct' 'Prof-specialty' 'Exec-managerial'
#  'Tech-support' 'Craft-repair' 'Sales' 'Other-service' '?'
#  'Transport-moving' 'Adm-clerical' 'Handlers-cleaners' 'Farming-fishing'
# ...

# %%
import numpy as np

# %%
new_data.replace("?",np.nan,inplace=True)

# %%
for i in new_data.columns:
    print(new_data[i].unique())
# Out:
# [28 44 63 65 48 43 40 34 45 46 36 22 42 41 55 33 59 29 27 31 58 54 37 56
#  39 51 50 52 47 24 64 53 35 32 30 68 57 66 49 38 61 73 26 23 25 62 90 60
#  67 69 72 85 71 77 70 19 21 74 75 20 81 76 80 88 78 79 84 17 18 82 83 86
#  87]
# ['Local-gov' 'Private' 'Self-emp-not-inc' 'State-gov' 'Self-emp-inc' nan
#  'Federal-gov' 'Without-pay' 'Never-worked']
# [336951 160323 104626 ...  84661 310152 257302]
# ['Assoc-acdm' 'Some-college' 'Prof-school' 'HS-grad' 'Masters' 'Doctorate'
#  'Bachelors' 'Assoc-voc' '9th' '10th' '7th-8th' '11th' '5th-6th' '1st-4th'
#  '12th' 'Preschool']
# [12 10 15  9 14 16 13 11  5  6  4  7  3  2  8  1]
# ['Married-civ-spouse' 'Never-married' 'Divorced' 'Separated'
#  'Married-AF-spouse' 'Widowed' 'Married-spouse-absent']
# ['Protective-serv' 'Machine-op-inspct' 'Prof-specialty' 'Exec-managerial'
#  'Tech-support' 'Craft-repair' 'Sales' 'Other-service' nan
#  'Transport-moving' 'Adm-clerical' 'Handlers-cleaners' 'Farming-fishing'
# ...

# %%
new_data.isnull().sum()
# Out:
# age                   0
# workclass          1283
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1288
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      508
# income                0
# dtype: int64

# %%
new_data["workclass"].mode()[0]
# Out:
# 'Private'

# %%
new_data["workclass"].fillna(new_data["workclass"].mode()[0],inplace=True)

# %%
new_data.isnull().sum()
# Out:
# age                   0
# workclass             0
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1288
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      508
# income                0
# dtype: int64

# %%
#linear regression
#y=b0+b1x1+b2x2+b3x3.....bnxn
#sales=b0+b1"TV"+b2"radio"+b3"newspaper"

# %%
X=df1[['TV', 'radio', 'newspaper']]

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [198 rows x 3 columns]

# %%
Y=df1[["sales"]]

# %%
Y
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [198 rows x 1 columns]

# %%
df1.shape
# Out:
# (198, 4)

# %%
X.shape
# Out:
# (198, 3)

# %%
Y.shape
# Out:
# (198, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2) #20-30 
# As per industry standards training data will be - 70%-80%
# testing data will be - (20%-30%)

# %%
print(X_train.shape)
print(X_test.shape)
print()
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (158, 3)
# (40, 3)
#
# (158, 1)
# (40, 1)

# %%
X_test
# Out:
#         TV  radio  newspaper
# 38    43.1   26.7       35.1
# 194  149.7   35.6        6.0
# 185  205.0   45.1       19.6
# 21   237.4    5.1       23.5
# 18    69.2   20.5       18.3
# 168  215.4   23.6       57.6
# 19   147.3   23.9       19.1
# 93   250.9   36.5       72.3
# 12    23.8   35.1       65.9
# 66    31.5   24.6        2.2
# 61   261.3   42.7       54.7
# 20   218.4   27.7       53.4
# 160  172.5   18.1       30.7
# 1     44.5   39.3       45.1
# 148   38.0   40.3       11.9
# 35   290.7    4.1        8.5
# 132    8.4   27.2        2.1
# 167  206.8    5.2       19.4
# 165  234.5    3.4       84.8
# 75    16.9   43.7       89.4
# 193  166.8   42.0        3.6
# 117   76.4    0.8       14.8
# 17   281.4   39.6       55.8
# 45   175.1   22.5       31.5
# 62   239.3   15.5       27.3
# 91    28.6    1.5       33.0
# 145  140.3    1.9        9.0
# 111  241.7   38.0       23.2
# 24    62.3   12.6       18.3
# 139  184.9   43.9        1.7
# 179  165.6   10.0       17.6
# ...

# %%
X_train
# Out:
#         TV  radio  newspaper
# 106   25.0   11.0       29.7
# 180  156.6    2.6        8.3
# 37    74.7   49.4       45.7
# 113  209.6   20.6       10.7
# 134   36.9   38.6       65.6
# ..     ...    ...        ...
# 152  197.6   23.3       14.2
# 147  243.2   49.0       44.3
# 107   90.4    0.3       23.2
# 123  123.1   34.6       12.4
# 133  219.8   33.5       45.1
#
# [158 rows x 3 columns]

# %%
Y_test
# Out:
#      sales
# 38    10.1
# 194   17.3
# 185   22.6
# 21    12.5
# 18    11.3
# 168   17.1
# 19    14.6
# 93    22.2
# 12     9.2
# 66     9.5
# 61    24.2
# 20    18.0
# 160   14.4
# 1     10.4
# 148   10.9
# 35    12.8
# 132    5.7
# 167   12.2
# 165   11.9
# 75     8.7
# 193   19.6
# 117    9.4
# 17    24.4
# 45    14.9
# 62    15.7
# 91     7.3
# 145   10.3
# 111   21.8
# 24     9.7
# 139   20.7
# 179   12.6
# 173   11.7
# 141   19.2
# 112   14.1
# 102   14.8
# 88    12.9
# 144   11.4
# 52    22.6
# 99    17.2
# 143   10.4

# %%
Y_train
# Out:
#      sales
# 106    7.2
# 180   10.5
# 37    14.7
# 113   15.9
# 134   10.8
# ..     ...
# 152   16.6
# 147   25.4
# 107    8.7
# 123   15.2
# 133   19.6
#
# [158 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#y=b0+b1x1+b2x2+b3x3

# %%
print(lm.coef_)
# Out:
# [[0.04613458 0.18379083 0.00213997]]

# %%
print(lm.intercept_)
# Out:
# [2.88938375]

# %%
x1=250
x2=14
x3=67
y=3.02202731+0.04550111*x1+0.18780856*x2+-0.00275615*x3

# %%
y
# Out:
# 16.8419626

# %%
x1=177
x2=9.3
x3=6.4
y=3.02202731+0.04550111*x1+0.18780856*x2+-0.00275615*x3

# %%
y
# Out:
# 12.804704028

# %%
Y_predict=lm.predict(X_test)

# %%
df2=pd.DataFrame()
df2=X_test
df2
# Out:
#         TV  radio  newspaper
# 38    43.1   26.7       35.1
# 194  149.7   35.6        6.0
# 185  205.0   45.1       19.6
# 21   237.4    5.1       23.5
# 18    69.2   20.5       18.3
# 168  215.4   23.6       57.6
# 19   147.3   23.9       19.1
# 93   250.9   36.5       72.3
# 12    23.8   35.1       65.9
# 66    31.5   24.6        2.2
# 61   261.3   42.7       54.7
# 20   218.4   27.7       53.4
# 160  172.5   18.1       30.7
# 1     44.5   39.3       45.1
# 148   38.0   40.3       11.9
# 35   290.7    4.1        8.5
# 132    8.4   27.2        2.1
# 167  206.8    5.2       19.4
# 165  234.5    3.4       84.8
# 75    16.9   43.7       89.4
# 193  166.8   42.0        3.6
# 117   76.4    0.8       14.8
# 17   281.4   39.6       55.8
# 45   175.1   22.5       31.5
# 62   239.3   15.5       27.3
# 91    28.6    1.5       33.0
# 145  140.3    1.9        9.0
# 111  241.7   38.0       23.2
# 24    62.3   12.6       18.3
# 139  184.9   43.9        1.7
# 179  165.6   10.0       17.6
# ...

# %%
df2["actual sales"]=Y_test
df2["predicted sales"]=Y_predict
# Out:
# <ipython-input-178-ed0c747d9758>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["actual sales"]=Y_test
# <ipython-input-178-ed0c747d9758>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["predicted sales"]=Y_predict

# %%
df2
# Out:
#         TV  radio  newspaper  actual sales  predicted sales
# 38    43.1   26.7       35.1          10.1         9.860112
# 194  149.7   35.6        6.0          17.3        16.351524
# 185  205.0   45.1       19.6          22.6        20.677882
# 21   237.4    5.1       23.5          12.5        14.829355
# 18    69.2   20.5       18.3          11.3         9.888770
# 168  215.4   23.6       57.6          17.1        17.287498
# 19   147.3   23.9       19.1          14.6        14.118482
# 93   250.9   36.5       72.3          22.2        21.327635
# 12    23.8   35.1       65.9           9.2        10.579469
# 66    31.5   24.6        2.2           9.5         8.868585
# 61   261.3   42.7       54.7          24.2        22.909274
# 20   218.4   27.7       53.4          18.0        18.170456
# 160  172.5   18.1       30.7          14.4        14.239910
# 1     44.5   39.3       45.1          10.4        12.261865
# 148   38.0   40.3       11.9          10.9        12.074734
# ...

# %%
lm.score(X_train,Y_train)
# Out:
# 0.8966669744718397

# %%
lm.score(X_train,Y_train)*100
# Out:
# 89.66669744718398

# %%
Y_test
# Out:
#      sales
# 38    10.1
# 194   17.3
# 185   22.6
# 21    12.5
# 18    11.3
# 168   17.1
# 19    14.6
# 93    22.2
# 12     9.2
# 66     9.5
# 61    24.2
# 20    18.0
# 160   14.4
# 1     10.4
# 148   10.9
# 35    12.8
# 132    5.7
# 167   12.2
# 165   11.9
# 75     8.7
# 193   19.6
# 117    9.4
# 17    24.4
# 45    14.9
# 62    15.7
# 91     7.3
# 145   10.3
# 111   21.8
# 24     9.7
# 139   20.7
# 179   12.6
# 173   11.7
# 141   19.2
# 112   14.1
# 102   14.8
# 88    12.9
# 144   11.4
# 52    22.6
# 99    17.2
# 143   10.4

# %%
Y_predi
# Out:
# 12.804704028

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
r2=r2_score(Y_test,Y_predict)
print("R-squarred:",r2)
rmse=np.sqrt(mean_squared_error(Y_test,Y_predict))
print("rmse:",rmse)
# Out:
# R-squarred: 0.8870176326442593
# rmse: 1.6462987000076452

# %%
import joblib

# %%
joblib.dump(lm,"model.pkl")
# Out:
# ['model.pkl']
